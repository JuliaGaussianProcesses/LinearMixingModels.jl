# %%
using Pkg
Pkg.activate(@__DIR__)

# %%
using AbstractGPs
using BenchmarkTools
using KernelFunctions
using LinearMixingModels
using LinearAlgebra
using Plots
using Random
using Statistics
using StatsBase;

# %%
using KernelFunctions: MOInputIsotopicByOutputs;

# %% [markdown]
# We will assume a setting similar to the defaults we see in MISO. This means 20 latent variables ($m$) with 600 outputs ($p$), ie $H \in \mathbb{R}^{600 \times 20}$, the mixing matrix, would be the first 20 Principal Components of PCA.
#
# For the purpose of this tutorial, we will randomly generate $H$, while enforcing orthogonality in the column space, as would be the case if they were the eigenvectors of the covariance obtained via PCA. We can do this via `svd`.

# %%
rng = Random.seed!(12345)
U, S, _ = svd(rand(600, 20));

# %% [markdown]
# An `ILMM` takes in a mixing matrix $H$ and a latent space multi-output GP, lets call it $f$. If $f$ is an `IndependentMOGP` and $H$ is `Orthogonal`, then we have an OILMM, as the orthogonality of $H$ decouples the latent processes, meaning we just have $m$ single-output GPs. We have constructors for both `Orthogonal` and `IndependentMOGP` types.
#
# Here we build $H$ and $f$.

# %%
H = Orthogonal(U, Diagonal(S))
sogp = GP(Matern52Kernel())
latent_gp = independent_mogp([sogp for _ in 1:20]);

# %% [markdown]
# For the purpose of this demo, we will construct an equivalent `ILMM` and `OILMM` to compare performance. The only difference, given an `IndependentMOGP` latent space GP, is that the `OILMM` expects an `Orthogonal` $H$, while the `ILMM` expects a `Matrix` $H$.

# %%
oilmm = ILMM(latent_gp, H);
ilmm = ILMM(latent_gp, Matrix(H));

# %% [markdown]
# The open source GP community uses Vectors of Tuples to represent [inputs to multi output GPs](https://juliagaussianprocesses.github.io/KernelFunctions.jl/stable/api/#Inputs-for-Multiple-Outputs). Each input is of the form `(features, output)`. As such, they can be ordered by `features` or by `outputs` using `MOInputIsotopicByFeatures` or `MOInputIsotopicByOutputs` respectively. `LinearMixingModels.jl` expects `MOInputIsotopicByOutputs`.
#
# Note:
# Heterotopic and missing data (semi-heterotopic) are not supported yet, however both cases can be addressed by [adding heterotopic support to the open source infrastructure](https://github.com/JuliaGaussianProcesses/KernelFunctions.jl/issues/358) and using the missing data techniques identified in the paper, as done in [OILMMs.jl](https://github.com/willtebbutt/OILMMs.jl/blob/master/src/missing_data.jl)
#
# First we construct our data locations.

# %%
x = range(0.0, 20.0; length=576)
indices = sort(sample(1:576, 24; replace=false))
x_train = [x[i] for i in 1:576 if i ∉ indices]
x_test = [x[i] for i ∈ indices]
x_train = MOInputIsotopicByOutputs(x_train, 600)
x_test = MOInputIsotopicByOutputs(x_test, 600);

# %% [markdown]
# We create a finite dimensional projection at the inputs of the training dataset observed under Gaussian noise with standard deviation $\sigma$ = `1e-6`, and compute the log-likelihood of the outputs of the training dataset.

# %%
@time ilmmx = ilmm(x_train, 1e-6);
# Out:
#   0.000022 seconds (13 allocations: 368 bytes)

# %%
@time oilmmx = oilmm(x_train, 1e-6);
# Out:
#   0.000018 seconds (13 allocations: 368 bytes)

# %% [markdown]
# We generate our data by sampling from the prior GP.

# %%
y_train = rand(rng, oilmmx);

# %%
@benchmark logpdf(ilmmx, y_train)
# Out:
# BenchmarkTools.Trial: 1 sample with 1 evaluation.
#  Single result which took 5.634 s (6.12% GC) to evaluate,
#  with a memory estimate of 3.73 GiB, over 265 allocations.

# %%
@benchmark logpdf(oilmmx, y_train)
# Out:
# BenchmarkTools.Trial: 30 samples with 1 evaluation.
#  Range (min … max):  147.352 ms … 198.175 ms  ┊ GC (min … max): 9.80% … 9.67%
#  Time  (median):     172.541 ms               ┊ GC (median):    9.59%
#  Time  (mean ± σ):   172.754 ms ±  14.527 ms  ┊ GC (mean ± σ):  9.45% ± 1.21%
#
#                              █      █
#   ▇▇▇▁▁▁▁▇▇▁▁▁▁▁▇▁▇▇▇▁▁▁▇▁▁▇▁█▇▁▁▁▇▁█▁▇▁▇▁▁▇▁▁▁▁▁▇▇▇▇▇▁▇▁▁▁▁▇▁▇ ▁
#   147 ms           Histogram: frequency by time          198 ms <
#
#  Memory estimate: 194.97 MiB, allocs estimate: 605.

# %% [markdown]
# We can take a look at what our first three outputs look like.

# %%
plot(x_train.x, y_train[1:552]; label = "Output 1")
plot!(x_train.x, y_train[553:1104]; label = "Output 2")
plot!(x_train.x, y_train[1105:1656]; label = "Output 3")

# %% [markdown]
# We compute the posterior Gaussian processes given the training data. Using these posteriors, which are `GPs` themselves, we can obtain a finite dimensional projection at the inputs of the test dataset. Similarily with the prior GP, we can then compute the log-likelihood of the outputs on the test dataset.

# %%
p_ilmmx = posterior(ilmmx, y_train)
# Out:
# ILMM{AbstractGPs.PosteriorGP{IndependentMOGP{Vector{GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}}}, NamedTuple{(:α, :C, :x, :δ), Tuple{Vector{Float64}, Cholesky{Float64, Matrix{Float64}}, MOInputIsotopicByOutputs{Float64, Vector{Float64}}, Vector{Float64}}}}, Matrix{Float64}}(AbstractGPs.PosteriorGP{IndependentMOGP{Vector{GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}}}, NamedTuple{(:α, :C, :x, :δ), Tuple{Vector{Float64}, Cholesky{Float64, Matrix{Float64}}, MOInputIsotopicByOutputs{Float64, Vector{Float64}}, Vector{Float64}}}}(IndependentMOGP{Vector{GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}}}(GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}[GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))), GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0)))]), (α = [-359.8409683419429, 1292.1846792666136, -2 ...

# %%
p_oilmmx = posterior(oilmmx, y_train)
# Out:
# OILMM{IndependentMOGP{Vector{AbstractGPs.PosteriorGP{GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}, NamedTuple{(:α, :C, :x, :δ), Tuple{Vector{Float64}, Cholesky{Float64, Matrix{Float64}}, Vector{Float64}, Vector{Float64}}}}}}, Orthogonal{Float64, Matrix{Float64}, Diagonal{Float64, Vector{Float64}}}}(IndependentMOGP{Vector{AbstractGPs.PosteriorGP{GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}, NamedTuple{(:α, :C, :x, :δ), Tuple{Vector{Float64}, Cholesky{Float64, Matrix{Float64}}, Vector{Float64}, Vector{Float64}}}}}}(AbstractGPs.PosteriorGP{GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}, NamedTuple{(:α, :C, :x, :δ), Tuple{Vector{Float64}, Cholesky{Float64, Matrix{Float64}}, Vector{Float64}, Vector{Float64}}}}[AbstractGPs.PosteriorGP{GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}, NamedTuple{(:α, :C, :x, :δ), Tuple{Vector{Float64}, Cholesky{Float64, Matrix{Float64}}, Vector{Float64}, Vector{Float64}}}}(GP{AbstractGPs.ZeroMean{Float64}, Matern52Kernel{Distances.Euclidean}}(AbstractGPs.ZeroMean{Float64}(), Matern 5/2 Kernel (metric = Distances.Euclidean(0.0))
�▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁█▁▁█▁▁▁▁▁█▁▁▁▁▁▁▁█▁▁█▁▁▁▁▁▁▁▁▁█ ▁
#   555 ms           Histogram: frequency by time          811 ms <
#
#  Memory estimate: 305.69 MiB, allocs estimate: 456.

# %%
marg_po = marginals(po)
# Out:
# 14400-element Vector{Distributions.Normal{Float64}}:
#  Distributions.Normal{Float64}(μ=0.05320227177927672, σ=0.0010386548644074802)
#  Distributions.Normal{Float64}(μ=-0.06528144377602425, σ=0.0010387195310521563)
#  Distributions.Normal{Float64}(μ=-0.1858891321023107, σ=0.0010387841896045003)
#  Distributions.Normal{Float64}(μ=-0.2903543853724129, σ=0.0010387195310605306)
#  Distributions.Normal{Float64}(μ=-0.3965822950436232, σ=0.001038654864533122)
#  Distributions.Normal{Float64}(μ=0.06475496500223965, σ=0.0010386548640442788)
#  Distributions.Normal{Float64}(μ=0.4417202175818957, σ=0.0010386548639493437)
#  Distributions.Normal{Float64}(μ=0.564132022976918, σ=0.0010386548658150182)
#  Distributions.Normal{Float64}(μ=-0.19951972141453578, σ=0.0010432513790651855)
#  Distributions.Normal{Float64}(μ=-0.22702553241437096, σ=0.0010432514400917116)
#  Distributions.Normal{Float64}(μ=-0.3253249316436897, σ=0.0010386549322517371)
#  Distributions.Normal{Float64}(μ=-0.4752327927879079, σ=0.0010386548722476731)
#  Distributions.Normal{Float64}(μ=-0.34282868695242147, σ=0.0010386548575234762)
#  ⋮
#  Distributions.Normal{Float64}(μ=1.7140602247238255, σ=0.0010532246739967366)
#  Distributions.Normal{Float64}(μ=1.298852346948496, σ=0.0010532278445234329)
#  Distributions.Normal{Float64}(μ=0.9435363153373425, σ=0.0010532278520180196)
#  Distributions.Normal{Float64}(μ=-0.029890951026203004, σ=0.0010532246828673089)
#  Distributions.Normal{Float64}(μ=-0.25691509713870336, σ=0.0010532246989049178)
#  Distributions.Normal{Float64}(μ=-0.5376952665169658, σ=0.001053224690042832)
#  Distributions.Normal{Float64}(μ=-1.6062013451133765, σ=0.0010535853012659272)
#  Distributions.Normal{Float64}(μ=-1.4800937800994571, σ=0.001053585297376594)
#  Distributions.Normal{Float64}(μ=-0.7176341842739327, σ=0.0010535852886943069)
#  Distributions.Normal{Float64}(μ=-0.7194787135445897, σ=0.0010535852918068125)
#  Distributions.Normal{Float64}(μ=-0.7012535783115865, σ=0.0010535852740185892)
#  Distributions.Normal{Float64}(μ=-0.7592650204164942, σ=0.0010535852826987985)

# %%
@benchmark rand_pi = rand(rng, p_i)
# Out:
# BenchmarkTools.Trial: 9 samples with 1 evaluation.
#  Range (min … max):  541.034 ms … 656.737 ms  ┊ GC (min … max): 0.00% … 10.57%
#  Time  (median):     578.937 ms               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   593.101 ms ±  35.379 ms  ┊ GC (mean ± σ):  1.30% ±  3.52%
#
#   █             █  ███         █            ██                █
#   █▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁███▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁██▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█ ▁
#   541 ms           Histogram: frequency by time          657 ms <
#
#  Memory estimate: 94.55 MiB, allocs estimate: 447.

# %%
rand_po = rand(rng, po)
# Out:
# 14400-element Vector{Float64}:
#   0.05276133062994811
#  -0.06433267717043456
#  -0.18608359637541658
#  -0.29156811965871443
#  -0.39768507315173235
#   0.06530071129273281
#   0.4402466783781891
#   0.564908396109441
#  -0.20000426269606697
#  -0.22744653768534437
#  -0.32457328166281585
#  -0.47348867293646246
#  -0.34128094344208165
#   ⋮
#   1.7146538124181023
#   1.2970700773910366
#   0.9436327609094465
#  -0.030269927024552414
#  -0.25747402278774495
#  -0.5394359031830787
#  -1.6051430749287432
#  -1.4802719169067184
#  -0.7179659470014634
#  -0.7197529537782588
#  -0.7007380760771685
#  -0.7599475551561597

# %%
plot(x_train.x, y_train[1:552]; label = "Output 1")
scatter!(x_test.x, mean.(marg_po[1:24]); ribbon_scale=std.(marg_po), label = "Output 1")

# %% [markdown]
# # Get better graphs

# %%
rng = Random.seed!(12345)
U, S, _ = svd(rand(3, 2));

# %%
H = Orthogonal(U, Diagonal(S))
gps = [GP(10, Matern52Kernel()), GP(0, Matern32Kernel())]
latent_gp = independent_mogp(gps);

# %%
oilmm = ILMM(latent_gp, H);
ilmm = ILMM(latent_gp, Matrix(H));

# %%
x = range(0.0, 20.0; length=1000)
indices = sort(sample(1:1000, 950; replace=false))
x_train = [x[i] for i in 1:1000 if i ∉ indices]
x_test = [x[i] for i in 1:1000 if i ∈ indices]
x_train = MOInputIsotopicByOutputs(x_train, 3)
x_test = MOInputIsotopicByOutputs(x_test, 3);

# %%
oilmm = ILMM(latent_gp, H);
ilmm = ILMM(latent_gp, Matrix(H));

# %%
ilmmx = ilmm(x_train, 1e-6);
oilmmx = oilmm(x_train, 1e-6);

# %%
y_train = rand(oilmmx);

# %%
scatter(x_train.x, y_train[1:50]; label = "Output 1")
scatter!(x_train.x, y_train[51:100]; label = "Output 2")
scatter!(x_train.x, y_train[101:150]; label = "Output 3")

# %%
p_ilmmx = posterior(ilmmx, y_train)
p_oilmmx = posterior(oilmmx, y_train);

# %%
p_i = p_ilmmx(x_test, 1e-6);
po = p_oilmmx(x_test, 1e-6);

# %%
marg_pi = marginals(p_i)
marg_po = marginals(po);;

# %%
rand_pi = rand(rng, p_i, 5)
rand_po = rand(rng, po, 5);

# %%
scatter(x_train.x, y_train[1:50]; label = "Output 1")
plot!(x_test.x, mean.(marg_pi[1:950]); ribbon=std.(marg_pi[1:950]), label = "Output 1")
scatter!(x_train.x, y_train[51:101]; label = "Output 2")
plot!(x_test.x, mean.(marg_pi[951:1900]); ribbon=std.(marg_pi[951:1900]), label = "Output 2")
scatter!(x_train.x, y_train[101:150]; label = "Output 3")
plot!(x_test.x, mean.(marg_pi[1901:2850]); ribbon=std.(marg_pi[1901:2850]), label = "Output 3")

# %%
scatter(x_train.x, y_train[1:50]; label = "Output 1")
plot!(x_test.x, rand_po[1:950,1:5]; label = "Output 1")
scatter!(x_train.x, y_train[51:101]; label = "Output 2")
plot!(x_test.x, rand_po[951:1900,1:5]; label = "Output 2")
scatter!(x_train.x, y_train[101:150]; label = "Output 3")
plot!(x_test.x, rand_po[1901:2850,1:5]; label = "Output 3")
